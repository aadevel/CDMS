# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# %matplotlib inline

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re

sns.set(font_scale=1.5)


dfall = pd.read_csv('Predictions-TPMT-PTEN.tsv', sep="\t")
# Out:
# <style>.container { width:100% !important; }</style>
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %%
df2=dfall[(dfall['pdbname']=="tpmt") & (dfall['resnum']<100) ].groupby(['mutres', 'resnum'])['pred'].first().unstack().fillna(0)
colormap = plt.cm.GnBu
sns.set(font_scale=1.4)
plt.figure(figsize=(40,12))
sns.heatmap(df2,linewidths=0.1 , square=True, cmap=colormap, linecolor='white')

# %%
dfall[dfall['pdbname']=="tpmt"].groupby('resnum')['pred'].mean().to_csv('per-residue-mean-pred.tsv',sep="\t")
